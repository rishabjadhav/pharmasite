# %%
pip install nltk spacy transformers medspacy scikit-learn xgboost tensorflow torch joblib
# Out:
# ...
#   Using cached spacy-3.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (27 kB)
# ...
#   Using cached transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# ...
#   Using cached medspacy-1.2.0.tar.gz (243 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached xgboost-2.1.1-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# ...
#   Using cached tensorflow-2.17.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.1 kB)
# ...
#   Using cached torch-2.4.1-cp311-none-macosx_11_0_arm64.whl.metadata (26 kB)
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.0 kB)
# ...
#   Using cached cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.4 kB)
# ...
#   Using cached preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.2 kB)
# ...

# %%
# Natural Language Processing Libraries
import nltk  # Natural Language Toolkit: For processing text, including tokenization, stemming, and building language models.
import spacy  # For advanced natural language processing, including named entity recognition, part-of-speech tagging, and text parsing.
import transformers  # Hugging Face Transformers: For leveraging pre-trained models (e.g., BERT, GPT) to handle tasks like text classification, summarization, and more.
import biobert_embedding  # For BioBERT, a model optimized for biomedical text processing, including clinical text and research papers.
import medspacy  # An extension of SpaCy for processing clinical/medical texts, including extracting medical terms and analyzing clinical documents.

# Machine Learning Libraries
import scikit_learn as sklearn  # For general machine learning models, including classification, regression, clustering, and evaluation metrics.
import xgboost  # For implementing gradient boosting decision trees, which is commonly used for high-performance classification and regression tasks.
import tensorflow as tf  # A deep learning framework for building and training neural networks, especially useful for large-scale machine learning models.
import torch  # PyTorch: A deep learning framework for building neural networks with dynamic computation graphs, popular for both research and production in ML.
import joblib  # For saving and loading trained machine learning models to disk, enabling model persistence and reuse.
